# %%
# !pip install matplotlib

# %%
# !pip install opencv-python

# %%
median = cv2.medianBlur(resized_image, 15)  
median_rgb = cv2.cvtColor(median, cv2.COLOR_BGR2RGB)  

plt.imshow(median_rgb)
plt.title('Median Blurred Image')
plt.axis('off')
plt.show() #OPTIONAL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 median = cv2.medianBlur(resized_image, 15)
#       2 median_rgb = cv2.cvtColor(median, cv2.COLOR_BGR2RGB)
#       4 plt.imshow(median_rgb)
#
# NameError: name 'cv2' is not defined

# %%
bilateral = cv2.bilateralFilter(resized_image, 20, 150, 150)  
bilateral_rgb = cv2.cvtColor(bilateral, cv2.COLOR_BGR2RGB)  

plt.imshow(bilateral_rgb)
plt.title('Bilateral Blurred Image')
plt.axis('off')
plt.show()

# %%
Gaussian = cv2.GaussianBlur(resized_image, (5, 15), 0)  
Gaussian_rgb = cv2.cvtColor(Gaussian, cv2.COLOR_BGR2RGB)  
plt.imshow(Gaussian_rgb)
plt.title('Gaussian Blurred Image')
plt.axis('off')
plt.show()

# %%
bilateral = cv2.bilateralFilter(resized_image, 20, 150, 150)  
bilateral_rgb = cv2.cvtColor(bilateral, cv2.COLOR_BGR2RGB)  

plt.imshow(bilateral_rgb)
plt.title('Bilateral Blurred Image')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np

# %%
canvas = np.ones((500, 500, 3), dtype="uint8") * 255

# %%
plt.imshow(canvas)

# %%
canvas = np.ones((500, 500, 3), dtype="uint8") * 255
cv2.rectangle(canvas, (100, 100), (400, 250), (0, 0,255), -2)
plt.imshow(canvas)

# %%
canvas = np.ones((500, 500, 3), dtype="uint8") * 255
cv2.circle(canvas, (250, 350), 50, (0, 0, 255), -1)
plt.imshow(canvas)

# %%
import cv2
import numpy as np

# Create white canvas
canvas = np.ones((600, 900, 3), dtype="uint8") * 255

# Drawing state variables
drawing = False
mode = "free"   # "free" or "rect"
color = (0, 0, 255)  # Default Red
thickness = 3
start_x, start_y = -1, -1


def mouse_events(event, x, y, flags, param):
    global drawing, start_x, start_y, canvas

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        start_x, start_y = x, y

    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            if mode == "free":
                cv2.circle(canvas, (x, y), thickness, color, -1)
            elif mode == "rect":
                temp = canvas.copy()
                cv2.rectangle(temp, (start_x, start_y), (x, y), color, thickness)
                cv2.imshow("OpenCV Draw App", temp)

    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        if mode == "rect":
            cv2.rectangle(canvas, (start_x, start_y), (x, y), color, thickness)


cv2.namedWindow("OpenCV Draw App")
cv2.setMouseCallback("OpenCV Draw App", mouse_events)     

print("""
======== OpenCV Drawing App ========

Press:
F  → Free draw mode
R  → Rectangle mode
1  → Red
2  → Green
3  → Blue
+  → Increase thickness
-  → Decrease thickness
C  → Clear canvas
S  → Save image
ESC → Exit

====================================
""")

while True:
    cv2.imshow("OpenCV Draw App", canvas)
    key = cv2.waitKey(1) & 0xFF

    # Mode switching
    if key == ord('f'):
        mode = "free"
    elif key == ord('r'):
        mode = "rect"

    # Color switching
    elif key == ord('1'):
        color = (0, 0, 255)  # Red
    elif key == ord('2'):
        color = (0, 255, 0)  # Green
    elif key == ord('3'):
        color = (255, 0, 0)  # Blue

    # Thickness control
    elif key == ord('+'):
        thickness += 1
    elif key == ord('-'):
        thickness = max(1, thickness - 1)

    # Clear
    elif key == ord('c'):
        canvas[:] = 255

    # Save
    elif key == ord('s'):
        cv2.imwrite("my_drawing.png", canvas)
        print("Saved as my_drawing.png")

    # Exit
    elif key == 27:
        break

cv2.destroyAllWindows()
# Out:
# ======== OpenCV Drawing App ========
#
# Press:
# F  → Free draw mode
# R  → Rectangle mode
# 1  → Red
# 2  → Green
# 3  → Blue
# +  → Increase thickness
# -  → Decrease thickness
# C  → Clear canvas
# S  → Save image
# ESC → Exit
#
# ...
#
# Saved as my_drawing.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 60
#      58 while True:
#      59     cv2.imshow("OpenCV Draw App", canvas)
# ---> 60     key = cv2.waitKey(1) & 0xFF
#      62     # Mode switching
#      63     if key == ord('f'):
#
# KeyboardInterrupt:
